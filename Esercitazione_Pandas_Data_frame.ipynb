# %% [markdown]
# <a href="https://colab.research.google.com/github/DavideColnago97/Lesson-Data-Analysis-with-Python-/blob/master/Esercitazione_Pandas_Data_frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt

# %% [markdown]
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
df=pd.DataFrame(data=[None],columns=[None],index=[None])

# %% [markdown]
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]
marvel_df=pd.DataFrame(data=marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ### Add column names to the `marvel_df`

# %%
marvel_df.columns=['Superhero','Gender','Date_of_creation']
marvel_df
# Out:
#            Superhero  Gender  Date_of_creation
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
 marvel_df.index=marvel_df['Superhero']

# %% [markdown]
# ### Drop the name column as it's now the index

# %%
marvel_df.drop(['Spider-Man'],axis=0)
# Out:
#                          Superhero  Gender  Date_of_creation
# Superhero
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# ...

# %%
marvel_df
# Out:
#                          Superhero  Gender  Date_of_creation
# Superhero
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %% [markdown]
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
marvel_df=marvel_df.drop(['Namor','Hank Pym'])

# %% [markdown]
# ## DataFrame selection, slicing and indexation
# ### Show the first 5 elements on `marvel_df`

# %%
marvel_df.head(5)
# Out:
#                        Superhero Gender  Date_of_creation
# Superhero
# Spider-Man            Spider-Man   male              1962
# Captain America  Captain America   male              1941
# Wolverine              Wolverine   male              1974
# Iron Man                Iron Man   male              1963
# Thor                        Thor   male              1963

# %%
marvel_df.iloc[0:6]
# Out:
#                        Superhero Gender  Date_of_creation
# Superhero
# Spider-Man            Spider-Man   male              1962
# Captain America  Captain America   male              1941
# Wolverine              Wolverine   male              1974
# Iron Man                Iron Man   male              1963
# Thor                        Thor   male              1963
# Thing                      Thing   male              1961

# %%
marvel_df.loc['Spider-Man':'Thing']
# Out:
#                        Superhero Gender  Date_of_creation
# Superhero
# Spider-Man            Spider-Man   male              1962
# Captain America  Captain America   male              1941
# Wolverine              Wolverine   male              1974
# Iron Man                Iron Man   male              1963
# Thor                        Thor   male              1963
# Thing                      Thing   male              1961

# %% [markdown]
# ### Show the last 5 elements on `marvel_df`

# %%
marvel_df.iloc[-5:]
# Out:
#                      Superhero  Gender  Date_of_creation
# Superhero
# Doctor Strange  Doctor Strange    male              1963
# Scarlet Witch    Scarlet Witch  female              1964
# Wasp                      Wasp  female              1963
# Black Widow        Black Widow  female              1964
# Vision                  Vision    male              1968

# %% [markdown]
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
marvel_df.iloc[:5,].Gender.to_frame()
# Out:
#                 Gender
# Superhero
# Spider-Man        male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %% [markdown]
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
#marvel_df.iloc[1:-1,].Date_of_creation.to_frame()
marvel_df.iloc[1:-1,][['Date_of_creation']]
# Out:
#                   Date_of_creation
# Superhero
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %% [markdown]
# ### Show the first and last elements on `marvel_df`

# %%
marvel_df.iloc[[0,-1]][['Gender']]
# Out:
#            Gender
# Superhero
# Spider-Man   male
# Vision       male

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
marvel_df.loc['Vision','Date_of_creation']=1964
marvel_df
# Out:
#                          Superhero  Gender  Date_of_creation
# Superhero
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# ...

# %% [markdown]
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
marvel_df['years-since']=2022-marvel_df['Date_of_creation']
marvel_df
# Out:
#                          Superhero  Gender  Date_of_creation  years-since
# Superhero
# Spider-Man              Spider-Man    male              1962           60
# Captain America    Captain America    male              1941           81
# Wolverine                Wolverine    male              1974           48
# Iron Man                  Iron Man    male              1963           59
# Thor                          Thor    male              1963           59
# Thing                        Thing    male              1961           61
# Mister Fantastic  Mister Fantastic    male              1961           61
# Hulk                          Hulk    male              1962           60
# Beast                        Beast    male              1963           59
# Invisible Woman    Invisible Woman  female              1961           61
# Storm                        Storm  female              1975           47
# Hawkeye                    Hawkeye    male              1964           58
# ...

# %% [markdown]
# ## DataFrame boolean arrays (also called masks)
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
mask=marvel_df['Gender']=='female'
marvel_df[mask]
# Out:
#                        Superhero  Gender  Date_of_creation  years-since
# Superhero
# Invisible Woman  Invisible Woman  female              1961           61
# Storm                      Storm  female              1975           47
# Scarlet Witch      Scarlet Witch  female              1964           58
# Wasp                        Wasp  female              1963           59
# Black Widow          Black Widow  female              1964           58

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
marvel_df[marvel_df['Gender']=='male']
# Out:
#                          Superhero Gender  Date_of_creation  years-since
# Superhero
# Spider-Man              Spider-Man   male              1962           60
# Captain America    Captain America   male              1941           81
# Wolverine                Wolverine   male              1974           48
# Iron Man                  Iron Man   male              1963           59
# Thor                          Thor   male              1963           59
# Thing                        Thing   male              1961           61
# Mister Fantastic  Mister Fantastic   male              1961           61
# Hulk                          Hulk   male              1962           60
# Beast                        Beast   male              1963           59
# Hawkeye                    Hawkeye   male              1964           58
# Daredevil                Daredevil   male              1964           58
# Doctor Strange      Doctor Strange   male              1963           59
# ...

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
marvel_df[marvel_df['Date_of_creation']>=1970]
# Out:
#            Superhero  Gender  Date_of_creation  years-since
# Superhero
# Wolverine  Wolverine    male              1974           48
# Storm          Storm  female              1975           47

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
marvel_df[(marvel_df['Date_of_creation']>=1970)&(marvel_df['Gender']=='female')]
# Out:
#           Superhero  Gender  Date_of_creation  years-since
# Superhero
# Storm         Storm  female              1975           47

# %% [markdown]
# ## DataFrame summary statistics
# ### Show basic statistics of `marvel_df`

# %%
marvel_df.describe()
# Out:
#        Date_of_creation  years-since
# count         18.000000    18.000000
# mean        1962.888889    59.111111
# std            6.720372     6.720372
# min         1941.000000    47.000000
# 25%         1962.000000    58.000000
# 50%         1963.000000    59.000000
# 75%         1964.000000    60.000000
# max         1975.000000    81.000000

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
marvel_df['Date_of_creation'].mean()
# Out:
# 1962.888888888889

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
marvel_df['Date_of_creation'].min()
# Out:
# 1941

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
marvel_df[marvel_df['Date_of_creation']==marvel_df['Date_of_creation'].min()]
# Out:
#                        Superhero Gender  Date_of_creation  years-since
# Superhero
# Captain America  Captain America   male              1941           81

# %% [markdown]
# ## DataFrame basic plottings
# ### Reset index names of `marvel_df`

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-07262d6a401f> in <module>()
# ----> 1 marvel_df = marvel_df.reset_index()
#       2
#       3 marvel_df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4857                 # to ndarray and maybe infer different dtype
#    4858                 level_values = _maybe_casted_values(lev, lab)
# -> 4859                 new_obj.insert(0, name, level_values)
#    4860
#    4861         new_obj.index = new_index
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3626         self._ensure_valid_index(value)
#    3627         value = self._sanitize_column(column, value, broadcast=False)
# ...

# %%
marvel_df.Date_of_creation.plot()

# %% [markdown]
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
plt.hist(marvel_df.Date_of_creation)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3., 12.,  0.,  0.,  2.]),
#  array([1941. , 1944.4, 1947.8, 1951.2, 1954.6, 1958. , 1961.4, 1964.8,
#         1968.2, 1971.6, 1975. ]),
#  <a list of 10 Patch objects>)
